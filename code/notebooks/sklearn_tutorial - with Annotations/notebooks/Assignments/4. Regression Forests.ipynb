# %% [markdown]
# # Regression Forests
#
# ### 1. Decision Trees and Random Forests
#
# #### (a) What is the relationship between Random Forests and Decision Trees?

# %% [markdown]
# ##### Student Response:
# >

# %% [markdown]
# #### (b) What issue does the Random Forest seek to mitigate? How does it accomplish this?

# %% [markdown]
# ##### Student Response:
# >

# %% [markdown]
# ### 2. Exploring Different Classifiers
#
# #### (a) Perform Random Forest Classification on the data generated below. Use the method `plotConfusion` to visualize your results. Be sure to fit the model using the training data (`featuresTrain` and `featuresTest`) and plot using all the sets. Explore the different parameters of the Random Forest Classifier to obtain different results.

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import seaborn as sns

features, labels = make_blobs(n_samples=300, centers=4, random_state=0, cluster_std=0.8)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow')
plt.show()

#method for visual representation of confusion matrix - citation at bottom
def plotConfusion(model, features, labels, labelNames):
    mat = confusion_matrix(labels, model.predict(features))
    sns.heatmap(mat.T,
        square=True, annot=True, cmap='Greens',
        xticklabels=labelNames, yticklabels=labelNames)
    plt.xlabel('True labels')
    plt.ylabel('Predicted labels')
    plt.show()
    print('Accuracy:', model.score(features, labels)*100, '%')
    
featuresTrain, featuresTest, labelsTrain, labelsTest = train_test_split(X, y, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
modelRF = RandomForestClassifier(n_estimators=100, random_state=0)

#Your code here

# %% [markdown]
# #### (b) Perform Support Vector Classification on the data generated below. Use the method plotConfusion to visualize your results. Explore the different parameters of the Support Vector Classifier to obtain different results. Comment on any differences in the range of accuracies you observe between SVC and Random Forest Classification.

# %%
from sklearn.svm import SVC

modelSVC = SVC(C=1.0, kernel='rbf', gamma='auto')

#Your code here

# %% [markdown]
# Sundararaman, Ravishankar. `plotConfusion`. _Classification_; Oct 21 2018.
